# %% [markdown]
# ## 1. Import pyplot package are present inside matplot lib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1(a). For changing Style

# %%
# plt.style.use('classic')

# %% [markdown]
# ### Some Common things

# %%
x = np.random.rand(50)

# %%
y = np.random.rand(50)

# %% [markdown]
# ### 1(i). Ploting Scatter plot

# %%
plt.scatter(x,y)

# %% [markdown]
# ### 1(iii). Makig DataFrame of random integer value with date

# %%
pd.DataFrame(np.random.randn(1000),columns=['data'],index=pd.date_range('2020/04/21',periods=1000))
# Out:
#                 data
# 2020-04-21  1.712992
# 2020-04-22 -1.191789
# 2020-04-23 -2.496844
# 2020-04-24  0.617798
# 2020-04-25  0.370058
# ...              ...
# 2023-01-11  0.057758
# 2023-01-12  1.662302
# 2023-01-13  2.310732
# 2023-01-14  1.763107
# 2023-01-15 -1.670088
#
# [1000 rows x 1 columns]

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['data'],index=pd.date_range('2020/04/21',periods=1000))

# %%
df
# Out:
#                 data
# 2020-04-21  1.091359
# 2020-04-22 -0.435969
# 2020-04-23  1.868539
# 2020-04-24 -0.282050
# 2020-04-25  0.402667
# ...              ...
# 2023-01-11  0.813235
# 2023-01-12 -0.662509
# 2023-01-13  2.209191
# 2023-01-14 -0.089289
# 2023-01-15 -0.796802
#
# [1000 rows x 1 columns]

# %% [markdown]
# ### 1(iv). Plotting plot

# %%
df.plot(figsize = (10,4))
# Out:
# <Axes: >

# %% [markdown]
# ## 2. MatplotLib

# %% [markdown]
# ### 2

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %% [markdown]
# ### 2(i). Ploting graph of x

# %%
plt.plot(x)

# %% [markdown]
# ### 2(ii). ploting graph of sin x

# %%
plt.plot(x,np.sin(x))

# %% [markdown]
# ### 3(ii). Ploting Graph of cos-x

# %%
plt.plot(x,np.cos(x))

# %% [markdown]
# ### 4(iii). Ploting both x and y

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %% [markdown]
# ### 2(iv). plotting with different modification using some key symbol
# ## (a)

# %%
plt.plot(x,np.sin(x),':')

# %% [markdown]
# ## (b)

# %%
plt.plot(x,np.sin(x),'--') # we also check with '.-','.',

# %% [markdown]
# ### 2(v). Just defining x and y limit

# %%
plt.plot(x,np.sin(x-0),color = 'red')
plt.ylim(-1.5, 1.5)
plt.xlim(1,15)
plt.show()

# %% [markdown]
# ### 2(vi). Making plot full fill in page just add [ plt.axis('equal') ]

# %%
plt.plot(x,np.sin(x-1),color = 'red')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### 2(vii).
# ## (a)
# ####  Adding Grid in plot and tittle

# %%
plt.plot(x,np.sin(x-1),color='red')
plt.ylim(-1.5,1.5)
plt.xlim(1.15)
plt.axis('equal') # Making equal axis for filling full page
plt.grid() # Adding grid
plt.title("this is sin plot before execution of real dataset")  # Adding title
plt.show()

# %% [markdown]
# ## (b)
# #### Adding Label of X and Y axis and adding sin and cos x with lable

# %%
plt.plot(x,np.sin(x-1),color = 'red',label = 'Sin-X')
plt.plot(x,np.cos(x-1),color = 'blue',label = 'Cos-X')
plt.xlim(1,15)
plt.ylim(-1.5,1.5)
#plt.axis('equal')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid()
plt.legend()  # Legen function gives the information about label inside plot

# %% [markdown]
# ## 3(i). Dividing a page in 2 part along Columns

# %% [markdown]
# #### plt.subplot(1,2,1) >> [1] 1 is Row, [2] 2 is Columns and [3] 1 is ploting figure in 1st column

# %%
plt.figure()  # Ploting page
plt.subplot(1,2,1) # 1- page, 2 - making 2 sub-page, ploting graph in 1 subpage
plt.plot(x,np.sin(x))

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2) # making plot in 2nd page
plt.plot(x,np.cos(x)) # ploting graph

# %% [markdown]
# ## 3(ii). Dividing a page in 2 part along Rows

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

# %% [markdown]
# ## 3(iii). Dividing a page in 4 Parts and also Changing Colours

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x), color = 'blue')

plt.subplot(2,2,2)
plt.plot(x,np.cos(x), color = 'green')

plt.subplot(2,2,3)
plt.plot(x,np.tan(x), color = 'red')

plt.subplot(2,2,4)
plt.plot(x,np.sin(x-1), color = 'skyblue')

# %% [markdown]
# ## 4. Ploting Histogram

# %%
# for Continous data we make histogram or distribution plot

data = np.random.randn(1000)

# %%
data
# Out:
# array([ 4.25884524e-02, -4.51697813e-01, -5.34847709e-01, -1.55837919e+00,
#        -8.36213949e-01,  1.31270314e+00, -1.04767947e+00, -1.24095356e-01,
#         1.01901337e+00, -4.75120772e-02, -8.57520791e-02, -8.76470728e-01,
#        -9.14172986e-01,  4.47999838e-01, -2.57673052e-01, -1.81073395e+00,
#         1.07662034e+00, -4.89811945e-01,  1.14901071e+00,  5.26704089e-01,
#        -4.94859683e-01,  4.54569038e-02, -2.06892202e+00, -3.54307525e-01,
#        -1.41342083e+00, -7.76493332e-01, -5.77874408e-01, -1.51821800e+00,
#         1.48414790e+00,  3.11151273e-01, -8.89290496e-01, -4.33889921e-01,
#        -5.83248059e-01, -9.82112429e-01, -1.37689564e-01, -1.68252913e+00,
#        -2.38952637e-01,  2.33059608e-01,  7.51946778e-01, -4.29530163e-02,
#        -2.00559961e-01,  9.18306429e-01, -3.07883166e+00,  8.32537459e-01,
#         1.17359314e+00, -1.38792926e+00, -3.24739010e-02,  1.94029748e-02,
#         3.00784627e-01,  3.06865480e-01, -1.44392870e-01,  7.85184338e-02,
#        -6.56930830e-01,  4.63764154e-02,  7.38945879e-02,  5.36072211e-01,
#        -7.16733083e-01, -7.18929643e-01, -1.63802110e-01, -5.04067477e-01,
#         5.19353227e-01, -7.37772895e-02, -5.80343200e-01,  1.45078325e+00,
#        -2.83461120e-01, -3.08908113e-01, -1.53640687e+00,  8.12497194e-01,
#        -6.61686164e-01,  3.11216229e-02,  3.78323214e-02, -2.93429552e-03,
#        -8.12548884e-01,  2.26187347e+00, -6.42747434e-01, -4.48303149e-01,
#        -3.65967303e-01, -1.28026026e+00,  9.45572852e-01,  9.28841334e-01,
#        -7.64872850e-01, -5.28436082e-01,  7.24179880e-01,  2.72268971e-01,
#        -6.37042439e-01, -7.46739374e-01,  6.22002169e-02,  1.26833960e+00,
#         6.31241300e-02, -4.82257490e-01, -4.80307493e-01, -1.84553465e+00,
#         1.01358009e+00, -1.52982135e-01,  1.20737370e+00, -7.32165691e-01,
